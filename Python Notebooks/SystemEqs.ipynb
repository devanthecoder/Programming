# %%
import scipy as sp
import numpy as np

# %%
#Example 1:

# %%
A = np.array([[1, 1, -1], [3, -1, 1], [1, -3, 2]], dtype=float)
A
# Out:
# array([[ 1.,  1., -1.],
#        [ 3., -1.,  1.],
#        [ 1., -3.,  2.]])

# %%
b = np.array([[0], [4], [1.02]], dtype=float)
b
# Out:
# array([[0.  ],
#        [4.  ],
#        [1.02]])

# %%
np.linalg.solve(A, b)
# Out:
# array([[1.  ],
#        [1.98],
#        [2.98]])

# %%
#Example 2:

# %%
C = np.array([[1, 1], [1.0001, 1]], dtype=float)
d = np.array([[2], [2.0002]], dtype=float)

# %%
np.linalg.solve(C, d)
# Out:
# array([[2.],
#        [0.]])

# %%
np.linalg.cond(A)
# Out:
# np.float64(13.786035815258492)

# %%
np.linalg.cond(C, p='fro')
# Out:
# np.float64(40002.00009999336)
